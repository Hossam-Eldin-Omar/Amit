# %%
print("Hello world!")
x = 22
# Out:
# Hello world!

# %%
print(f"I am {x} years old.")
# Out:
# I am 22 years old.

# %%
name = "Hossam Eldin"
age = 22
course = "Python for ML"
print(f"My name is {name}, and I am {age} years old. I am engaged in learning {course}.")
# Out:
# My name is Hossam Eldin, and I am 22 years old. I am engaged in learning Python for ML.

# %%
sent = "Welcome to Depi round 4 with machine learning."
split_sent = sent.split()
" ".join(split_sent)
# Out:
# 'Welcome to Depi round 4 with machine learning.'

# %%
print("hello \"wolrd\"")
print('hello world\b')
# Out:
# hello "wolrd"
# hello worl

# %%
str = "fasjofjaosfj@gmail.com"
mail = str.split("@")[-1]
mail
mail.startswith("gmail.com")
# Out:
# True

# %%
#find the location of the last character 'f' in the string
next(i for i in range(len(str)-1, -1, -1) if str[i] == 'f')
# Out:
# 10
